# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
load_dotenv(override=True)
# Out:
# True

# %%
#   
# api_key_openai=os.getenv("OPENAI_API_KEY")
openai_key=os.getenv("OPENAI_API_KEY")   
client=OpenAI(api_key=openai_key)

# %%
# System prompt — defined once, before the loop
messages = [{"role": "system", "content": "You are a helpful assistant who gives clear and concise answers"}
            ,{"role":"assistant","content":"Hi! How can I help you Today?"}]

while True:
    user_input = input("You: ")
     # ← user role here

    
    if user_input.lower()=='quit':
        break
    messages.append({"role":"user", "content": user_input}) 
    
    response = client.chat.completions.create(
        model="gpt-4o-mini", 
        messages=messages
        )
    reply=response.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    
    print(reply)
# Out:
# It looks like your message didn't come through. How can I assist you today?
# It seems like your messages are still not coming through. If you have a question or need assistance with something, please try typing it again!
# It appears there may be a technical issue, as I’m not receiving your messages. Please try sending your question or comment again. I’m here to help!
# Hello! How can I assist you today?
# Artificial intelligence (AI) is the ability of a computer or a machine to imitate human thinking or behavior. In simple terms, it's like teaching a computer to learn, solve problems, and make decisions on its own, much like a human would. For example, AI powers voice assistants like Siri or Google Assistant, which can understand your questions and respond with useful information.
# If you would like to end our conversation, that's perfectly fine! Feel free to return anytime if you have more questions. Have a great day!

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv



load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

messages=[{'role':'system','content':'You are a helpful assistant who gives clear and concise answers'}]
def chat(messages, user_message):
    
    messages.append({"role": "user", "content": user_message})

    
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    )
    reply=response.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    return reply



while True:
    user_input = input("You: ")
    if user_input.lower() == "quit":
        break
    #messages.append({'role':'user','content': user_input})

    reply = chat(messages, user_input)
    #messages.append(reply)
    print(f"Assistant: {reply}")
# Out:
# Assistant: Hello! How can I assist you today?
# Assistant: Federated learning is a decentralized machine learning approach that enables multiple devices or servers to collaboratively train a shared model while keeping their data local. Instead of sending raw data to a central server, each participant (device or organization) trains the model on its own data and only shares the model updates (such as gradients) with the central server. The server then aggregates these updates to improve the global model.
#
# Key benefits of federated learning include:
#
# 1. **Data Privacy**: Since raw data never leaves the local devices, sensitive information remains secure.
# 2. **Reduced Bandwidth Usage**: Only model updates are transmitted, reducing the need for large data transfers.
# 3. **Personalization**: Models can be more easily tailored to specific local datasets without compromising privacy.
#
# ...
